# %%
import algo_top
# Change algo_top.py line 16 to "pytorch"
# Out:
# Shape of the Inputs:  (1518, 22)
# Specs of the Model:
#    Design Framework:  tensorflow
#    Num. of Inputs:  22
#    Num. of Outputs:  2
#    Num. of True Layers:  6
#    Num. of All Layers (fake and true):  10
# ...
# 48/48 [==============================] - 0s 3ms/step

# %%
algo_top.display_explanation_of_instance(7)
# Out:
# Input Values:  [5.00000000e-01 6.47727400e-01 6.66666700e-01 5.59408900e-01
#  6.31541970e-01 4.65937800e-01 6.00599200e-01 1.11380816e-01
#  1.84914590e-01 3.99109780e-01 7.11418330e-01 5.47474600e-01
#  6.50733800e-01 3.03086530e-04 2.31675840e-02 4.50546270e-04
#  0.00000000e+00 6.42990100e-01 8.31695560e-01 2.37353530e-01
#  5.09479000e-01 3.93594500e-01]
# Output Pred. by NN:  [0.5361931324005127, 0.6419571042060852]
# Output Pred. by LF:  [0.5361931364883746, 0.641957125372794]
#   For Output Dimension  1
# ...

# %% [markdown]
# ### Three explorations for point 7 from the dataset:

# %%
algo_top.plot_explanation_performance(7, 10000, 0.1, True, "all")
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %%
algo_top.plot_explanation_performance(7, 10000, 0.5, True, "all")
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %%
algo_top.plot_explanation_performance(7, 10000, 1, True, "all")
# Out:
# 313/313 [==============================] - 1s 2ms/step
